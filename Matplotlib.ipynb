# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %%
'''
Matplotlib is a python library used to visualize data using a variety of different types of plots. The Pyplot module of 
Matplotlib provides a user with the ability to plot different types of plots by writing a few lines of code in python.


Five plots that can be plotted using the Pyplot module of Matplotlib are:
Line Plot
Histogram
Scatter Plot
3D Plot
Image Plot'''
# Out:
# '\nMatplotlib is a python library used to visualize data using a variety of different types of plots. The Pyplot module of \nMatplotlib provides a user with the ability to plot different types of plots by writing a few lines of code in python.\n\n\nFive plots that can be plotted using the Pyplot module of Matplotlib are:\nLine Plot\nHistogram\nScatter Plot\n3D Plot\nImage Plot'

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.title("Matplotlib scatter plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
import numpy as np
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])

import matplotlib.pyplot as plt
fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Plot 1')

axs[0, 1].plot(x2, y2)
axs[0, 1].set_title('Plot 2')

axs[1, 0].plot(x3, y3)
axs[1, 0].set_title('Plot 3')

axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Plot 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %%
#Bar plot is used to plot horizontal and vertical bar plot 
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])


plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %%
#Box plot is used to  is used for displaying the distribution of data based on a five-number summary: minimum, first quartile (Q1), 
#median (second quartile, Q2), third quartile (Q3), and maximum. It helps to visualize the central tendency, dispersion, and skewness 
#of the data, as well as identify potential outliers.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)


fig, axs = plt.subplots(1, 2)
axs[ 0].boxplot(box1)
axs[ 0].set_title('Plot 1')
axs[ 1].boxplot(box2)
axs[1].set_title('Plot 2')
# Out:
# Text(0.5, 1.0, 'Plot 2')
